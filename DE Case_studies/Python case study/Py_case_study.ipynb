# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r'C:\Users\nikhi\OneDrive\Pictures\Documents\daerah-working-set.csv',encoding='latin1')

# %%
data
# Out:
#      States    District        Town       Lat         Lon
# 0     Johor  Batu Pahat  Batu Pahat  1.954400     102.855
# 1     Johor  Batu Pahat  Batu Pahat  1.839100    103.1269
# 2     Johor  Batu Pahat  Batu Pahat  1.865900    103.1578
# 3     Johor  Batu Pahat  Batu Pahat  1.919000      102.92
# 4     Johor  Batu Pahat  Batu Pahat  1.862000     103.092
# ...     ...         ...         ...       ...         ...
# 1443     WP   Putrajaya   Putrajaya  2.908300    101.6787
# 1444     WP   Putrajaya   Putrajaya  2.950277  101.720735
# 1445     WP   Putrajaya   Putrajaya  2.932790  101.677648
# 1446     WP   Putrajaya   Putrajaya  2.957649  101.693098
# 1447     WP   Putrajaya   Putrajaya  2.962963   101.66958
#
# [1448 rows x 5 columns]

# %%
data.head(15)
# Out:
#    States     District         Town       Lat         Lon
# 0   Johor   Batu Pahat   Batu Pahat  1.954400     102.855
# 1   Johor   Batu Pahat   Batu Pahat  1.839100    103.1269
# 2   Johor   Batu Pahat   Batu Pahat  1.865900    103.1578
# 3   Johor   Batu Pahat   Batu Pahat  1.919000      102.92
# 4   Johor   Batu Pahat   Batu Pahat  1.862000     103.092
# 5   Johor   Batu Pahat   Batu Pahat  1.741000     103.044
# 6   Johor   Batu Pahat   Batu Pahat  1.853000     102.936
# 7   Johor   Batu Pahat   Batu Pahat  1.851955  102.931538
# 8   Johor   Batu Pahat   Batu Pahat  1.847132  102.926561
# 9   Johor   Batu Pahat   Batu Pahat  1.856777    2.926379
# 10  Johor   Batu Pahat   Batu Pahat  1.846452  102.937253
# 11  Johor   Batu Pahat   Batu Pahat  1.853458  102.934856
# 12  Johor   Batu Pahat   Batu Pahat  1.841035  102.931884
# 13  Johor   Batu Pahat   Batu Pahat  1.836635  102.922609
# 14  Johor  Johor Bahru  Johor Bahru  1.497500    103.6163

# %%
data.columns
# Out:
# Index(['States', 'District', 'Town', 'Lat', 'Lon'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1448 entries, 0 to 1447
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   States    1448 non-null   object
#  1   District  1448 non-null   object
#  2   Town      1448 non-null   object
#  3   Lat       1448 non-null   float64
#  4   Lon       1448 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 56.7+ KB

# %%
data.describe()
# Out:
#                Lat
# count  1448.000000
# mean      4.036241
# std       1.519324
# min       1.010400
# 25%       2.765592
# 50%       3.993156
# 75%       5.384650
# max       6.924400

# %%
 
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  States      0
# District    0
# Town        0
# Lat         0
# Lon         0
# dtype: int64

# %%
 
data.dropna()
# Out:
#      States    District        Town       Lat         Lon
# 0     Johor  Batu Pahat  Batu Pahat  1.954400     102.855
# 1     Johor  Batu Pahat  Batu Pahat  1.839100    103.1269
# 2     Johor  Batu Pahat  Batu Pahat  1.865900    103.1578
# 3     Johor  Batu Pahat  Batu Pahat  1.919000      102.92
# 4     Johor  Batu Pahat  Batu Pahat  1.862000     103.092
# ...     ...         ...         ...       ...         ...
# 1443     WP   Putrajaya   Putrajaya  2.908300    101.6787
# 1444     WP   Putrajaya   Putrajaya  2.950277  101.720735
# 1445     WP   Putrajaya   Putrajaya  2.932790  101.677648
# 1446     WP   Putrajaya   Putrajaya  2.957649  101.693098
# 1447     WP   Putrajaya   Putrajaya  2.962963   101.66958
#
# [1448 rows x 5 columns]

# %%
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 2

# %%
data.drop_duplicates()
# Out:
#      States    District        Town       Lat         Lon
# 0     Johor  Batu Pahat  Batu Pahat  1.954400     102.855
# 1     Johor  Batu Pahat  Batu Pahat  1.839100    103.1269
# 2     Johor  Batu Pahat  Batu Pahat  1.865900    103.1578
# 3     Johor  Batu Pahat  Batu Pahat  1.919000      102.92
# 4     Johor  Batu Pahat  Batu Pahat  1.862000     103.092
# ...     ...         ...         ...       ...         ...
# 1443     WP   Putrajaya   Putrajaya  2.908300    101.6787
# 1444     WP   Putrajaya   Putrajaya  2.950277  101.720735
# 1445     WP   Putrajaya   Putrajaya  2.932790  101.677648
# 1446     WP   Putrajaya   Putrajaya  2.957649  101.693098
# 1447     WP   Putrajaya   Putrajaya  2.962963   101.66958
#
# [1446 rows x 5 columns]

# %%
data['Country']='Malaysia'  #add country column
data
# Out:
#      States    District        Town       Lat         Lon   Country
# 0     Johor  Batu Pahat  Batu Pahat  1.954400     102.855  Malaysia
# 1     Johor  Batu Pahat  Batu Pahat  1.839100    103.1269  Malaysia
# 2     Johor  Batu Pahat  Batu Pahat  1.865900    103.1578  Malaysia
# 3     Johor  Batu Pahat  Batu Pahat  1.919000      102.92  Malaysia
# 4     Johor  Batu Pahat  Batu Pahat  1.862000     103.092  Malaysia
# ...     ...         ...         ...       ...         ...       ...
# 1443     WP   Putrajaya   Putrajaya  2.908300    101.6787  Malaysia
# 1444     WP   Putrajaya   Putrajaya  2.950277  101.720735  Malaysia
# 1445     WP   Putrajaya   Putrajaya  2.932790  101.677648  Malaysia
# 1446     WP   Putrajaya   Putrajaya  2.957649  101.693098  Malaysia
# 1447     WP   Putrajaya   Putrajaya  2.962963   101.66958  Malaysia
#
# [1448 rows x 6 columns]

# %%
data.sort_values(by='Lon', ascending=True).head()
# Out:
#      States      District          Town     Lat       Lon   Country
# 916  Perlis  Kuala Perlis  Kuala Perlis  6.3968  100.1296  Malaysia
# 917  Perlis  Kuala Perlis  Kuala Perlis  6.4056  100.1464  Malaysia
# 920  Perlis  Kuala Perlis  Kuala Perlis  6.3865  100.1469  Malaysia
# 921  Perlis  Kuala Perlis  Kuala Perlis  6.4072  100.1491  Malaysia
# 918  Perlis  Kuala Perlis  Kuala Perlis  6.4151  100.1492  Malaysia

# %%
#retriving a specific row using index value
data.iloc[0]
# Out:
# States           Johor
# District    Batu Pahat
# Town        Batu Pahat
# Lat             1.9544
# Lon            102.855
# Name: 0, dtype: object

# %%
#retriving a specific row using condition
data.loc[data['States'] == 'Johor']
# Out:
#     States    District        Town       Lat         Lon   Country
# 0    Johor  Batu Pahat  Batu Pahat  1.954400     102.855  Malaysia
# 1    Johor  Batu Pahat  Batu Pahat  1.839100    103.1269  Malaysia
# 2    Johor  Batu Pahat  Batu Pahat  1.865900    103.1578  Malaysia
# 3    Johor  Batu Pahat  Batu Pahat  1.919000      102.92  Malaysia
# 4    Johor  Batu Pahat  Batu Pahat  1.862000     103.092  Malaysia
# ..     ...         ...         ...       ...         ...       ...
# 97   Johor     Tangkak     Tangkak  2.287500    102.5507  Malaysia
# 98   Johor     Tangkak     Tangkak  2.238004  102.515669  Malaysia
# 99   Johor     Tangkak     Tangkak  2.298039  102.567168  Malaysia
# 100  Johor     Tangkak     Tangkak  2.279514  102.530432  Malaysia
# 101  Johor     Tangkak     Tangkak  2.268365  102.555838  Malaysia
#
# [102 rows x 6 columns]

# %%
#retriving a specific row using multiple conditions
data.loc[(data['States'] == 'Johor') & (data['Town']=='Batu Pahat')]
# Out:
#    States    District        Town       Lat         Lon
# 0   Johor  Batu Pahat  Batu Pahat  1.954400     102.855
# 1   Johor  Batu Pahat  Batu Pahat  1.839100    103.1269
# 2   Johor  Batu Pahat  Batu Pahat  1.865900    103.1578
# 3   Johor  Batu Pahat  Batu Pahat  1.919000      102.92
# 4   Johor  Batu Pahat  Batu Pahat  1.862000     103.092
# 5   Johor  Batu Pahat  Batu Pahat  1.741000     103.044
# 6   Johor  Batu Pahat  Batu Pahat  1.853000     102.936
# 7   Johor  Batu Pahat  Batu Pahat  1.851955  102.931538
# 8   Johor  Batu Pahat  Batu Pahat  1.847132  102.926561
# 9   Johor  Batu Pahat  Batu Pahat  1.856777    2.926379
# 10  Johor  Batu Pahat  Batu Pahat  1.846452  102.937253
# 11  Johor  Batu Pahat  Batu Pahat  1.853458  102.934856
# 12  Johor  Batu Pahat  Batu Pahat  1.841035  102.931884
# 13  Johor  Batu Pahat  Batu Pahat  1.836635  102.922609

# %%
#merging data sets
pd.merge(data,data, on='Lon',how='inner')
# Out:
#      States_x  District_x      Town_x     Lat_x         Lon States_y  \
# 0       Johor  Batu Pahat  Batu Pahat  1.954400     102.855    Johor
# 1       Johor  Batu Pahat  Batu Pahat  1.839100    103.1269    Johor
# 2       Johor  Batu Pahat  Batu Pahat  1.865900    103.1578    Johor
# 3       Johor  Batu Pahat  Batu Pahat  1.919000      102.92    Johor
# 4       Johor  Batu Pahat  Batu Pahat  1.862000     103.092    Johor
# ...       ...         ...         ...       ...         ...      ...
# 1475       WP   Putrajaya   Putrajaya  2.908300    101.6787       WP
# 1476       WP   Putrajaya   Putrajaya  2.950277  101.720735       WP
# 1477       WP   Putrajaya   Putrajaya  2.932790  101.677648       WP
# 1478       WP   Putrajaya   Putrajaya  2.957649  101.693098       WP
# 1479       WP   Putrajaya   Putrajaya  2.962963   101.66958       WP
#
#       District_y      Town_y     Lat_y
# 0     Batu Pahat  Batu Pahat  1.954400
# 1     Batu Pahat  Batu Pahat  1.839100
# ...

# %%
import matplotlib.pyplot as plt

# Latitude and Longitude data
lat = data['Lat']
lon = data['Lon']
# Scatter plot
plt.scatter(lon, lat)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs Longitude')
plt.show()
