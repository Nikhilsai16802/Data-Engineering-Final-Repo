# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('coding_challenge').getOrCreate()
loan = spark.read.csv("/FileStore/tables/loan.csv", header=True, inferSchema= True)   #original table name = loan_csv
 
loan.createOrReplaceTempView("loan")

# %%
#Filter with pyspark and spark sql

#pyspark
onelakh_loan= loan.filter(loan["Loan Amount"] > '100000').count()
print('people who took loan greather than 1 lakh (pyspark): ', onelakh_loan)

#spark sql
print('\npeople who took loan greather than 1 lakh (spark sql): ')
spark.sql("select count(*) as Count from loan where `Loan Amount` >'100000'").show()
# Out:
# people who took loan greather than 1 lakh (pyspark):  279
#
# people who took loan greather than 1 lakh (spark sql):
# +-----+
# |Count|
# +-----+
# |  279|
# +-----+

# %%
 from pyspark.sql.functions import sum,max,min,avg,count, mean, count

# Calculate total income amount
income = loan.agg(sum("Income").alias("total_income"))
print("Total income (pyspark): ",income.show())

print("\nTotal income (spark sql):")
spark.sql("select sum(Income)  from loan").show()
# Out:
# +------------+
# |total_income|
# +------------+
# |    31982882|
# +------------+
#
# Total income (pyspark):  None
#
# Total income (spark sql):
# +-----------+
# |sum(Income)|
# +-----------+
# |   31982882|
# +-----------+

# %%
#max income
income = loan.agg(max("Income").alias("max_income"))
print("Max income (pyspark): ",income.show())

print("\nMax income (spark sql):")
spark.sql("select max(Income)  from loan").show()
# Out:
# +----------+
# |max_income|
# +----------+
# |    930000|
# +----------+
#
# Max income (pyspark):  None
#
# Max income (spark sql):
# +-----------+
# |max(Income)|
# +-----------+
# |     930000|
# +-----------+

# %%
#min income
income = loan.agg(min("Income").alias("min_income"))
print("Minincome (pyspark): ",income.show())

print("\nMin income (spark sql):")
spark.sql("select min(Income)  from loan").show()
# Out:
# +----------+
# |min_income|
# +----------+
# |     28366|
# +----------+
#
# Minincome (pyspark):  None
#
# Min income (spark sql):
# +-----------+
# |min(Income)|
# +-----------+
# |      28366|
# +-----------+

# %%
#avg income
income = loan.agg(avg("Income").alias("avg_incomet"))
print("avg income (pyspark): ",income.show())

print("\nAvg income (spark sql):")
spark.sql("select avg(Income)  from loan").show()
# Out:
# +-----------------+
# |      avg_incomet|
# +-----------------+
# |68339.49145299145|
# +-----------------+
#
# avg income (pyspark):  None
#
# Avg income (spark sql):
# +-----------------+
# |      avg(Income)|
# +-----------------+
# |68339.49145299145|
# +-----------------+

# %%
#mean income
income = loan.agg(mean("Income").alias("Mean income"))
print("Mean income (pyspark): ",income.show())

print("\nMean income (spark sql)")
spark.sql("select mean(Income)  from loan").show()
# Out:
# +-----------------+
# |      Mean income|
# +-----------------+
# |68339.49145299145|
# +-----------------+
#
# Mean income (pyspark):  None
#
# Mean income (spark sql)
# +-----------------+
# |     mean(Income)|
# +-----------------+
# |68339.49145299145|
# +-----------------+

# %%
from pyspark.sql.functions import count

# Count the number of non-null entries in the 'Income' column
income_count = loan.agg(count("Income").alias("Income_Count"))

print("Count of Income (PySpark):")
income_count.show()

print("\nCount of Income (Spark SQL):")
spark.sql("SELECT count(Income) AS Income_Count FROM loan").show()
# Out:
# Count of Income (PySpark):
# +------------+
# |Income_Count|
# +------------+
# |         468|
# +------------+
#
#
# Count of Income (Spark SQL):
# +------------+
# |Income_Count|
# +------------+
# |         468|
# +------------+

# %%
#Group By
a=loan.groupBy("Loan Category").min("Income")
print('Minimun income in each loan category(py spark):', a.show())

spark.sql("select `Loan Category`, min(Income) as min_income from loan GROUP BY `Loan Category`").show()
# Out:
# +------------------+-----------+
# |     Loan Category|min(Income)|
# +------------------+-----------+
# |           HOUSING|      29565|
# |        TRAVELLING|      30000|
# |       BOOK STORES|      34275|
# |       AGRICULTURE|      32571|
# |         GOLD LOAN|      28366|
# |  EDUCATIONAL LOAN|      35247|
# |        AUTOMOBILE|      30000|
# |          BUSINESS|      40883|
# |COMPUTER SOFTWARES|      31747|
# |           DINNING|      33312|
# |          SHOPPING|      30454|
# |       RESTAURANTS|      30000|
# |       ELECTRONICS|      34836|
# |          BUILDING|      48613|
# |        RESTAURANT|      35735|
# |   HOME APPLIANCES|      45389|
# +------------------+-----------+
#
# Minimun income in each loan category(py spark): None
# +------------------+----------+
# |     Loan Category|min_income|
# +------------------+----------+
# |           HOUSING|     29565|
# |        TRAVELLING|     30000|
# |       BOOK STORES|     34275|
# |       AGRICULTURE|     32571|
# |         GOLD LOAN|     28366|
# |  EDUCATIONAL LOAN|     35247|
# |        AUTOMOBILE|     30000|
# |          BUSINESS|     40883|
# |COMPUTER SOFTWARES|     31747|
# |           DINNING|     33312|
# |          SHOPPING|     30454|
# |       RESTAURANTS|     30000|
# |       ELECTRONICS|     34836|
# |          BUILDING|     48613|
# |        RESTAURANT|     35735|
# |   HOME APPLIANCES|     45389|
# +------------------+----------+

# %%
#joins
risk_data = [
    ("HOUSING", "High Risk"),
    ("SHOPPING", "Low Risk"),
    ("TRAVELLING", "Medium Risk"),
    ("GOLD LOAN", "Medium Risk"),
    ("AUTOMOBILE", "High Risk"),
]
risk_df = spark.createDataFrame(risk_data, ["Loan Category", "Risk Level"])

# Register risk DataFrame as a temporary SQL view
risk_df.createOrReplaceTempView("risk")

# %%
#Inner join
print("Inner Join (PySpark)")
loan.join(risk_df, on="Loan Category", how="inner").display(5)

# SparkSQL Joins
print("Inner Join (SparkSQL)")
spark.sql("""
    SELECT l.*, r.`Risk Level`
    FROM loan l
    JOIN risk r
    ON l.`Loan Category` = r.`Loan Category`
""").show(5)
# Out:
# Inner Join (PySpark)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Loan Category</th><th>Customer_ID</th><th>Age</th><th>Gender</th><th>Occupation</th><th>Marital Status</th><th>Family Size</th><th>Income</th><th>Expenditure</th><th>Use Frequency</th><th>Loan Amount</th><th>Overdue</th><th> Debt Record</th><th> Returned Cheque</th><th> Dishonour of Bill</th><th>Risk Level</th></tr></thead><tbody><tr><td>HOUSING</td><td>IB15107</td><td>46</td><td>FEMALE</td><td>CHARTERED APPRAISER</td><td>MARRIED</td><td>2</td><td>85088</td><td>44256</td><td>5</td><td>347,254</td><td>9</td><td>37966</td><td>1</td><td>5</td><td>High Risk</td></tr><tr><td>HOUSING</td><td>IB15095</td><td>53</td><td>FEMALE</td><td>SOFTWARE ENGINEER</td><td>SINGLE</td><td>4</td><td>75210</td><td>26027</td><td>7</td><td>740,375</td><td>7</td><td>35419</td><td>2</td><td>4</td><td>High Risk</td></tr><tr><td>HOUSING</td><td>IB15091</td><td>42</td><td>MALE</td><td>AGRICULTURAL ENGINEER</td><td>MARRIED</td><td>2</td><td>66610</td><td>35744</td><td>4</td><td>582,943</td><td>8</td><td>28192</td><td>0</td><td>8</td><td>High Risk</td></tr><tr><td>HOUSING</td><td>I

# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# only showing top 5 rows

# %%
#outer join
print("Outer Join (PySpark)")
loan.join(risk_df, on="Loan Category", how="outer").show(5)

print("Outer Join (SparkSQL)")
spark.sql("""
    SELECT l.*, r.`Risk Level`
    FROM loan l
    FULL OUTER JOIN risk r
    ON l.`Loan Category` = r.`Loan Category`
""").show(5)
# Out:
# Outer Join (PySpark)
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |Loan Category|Customer_ID|Age|Gender|          Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill|Risk Level|
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |  AGRICULTURE|    IB14589| 56|  MALE|              FARMER|        SINGLE|          3| 51162|      12591|            9|    104,758|      3|       75535|               2|                 1|      null|
# |  AGRICULTURE|    IB14604| 52|  MALE|          ACCOUNTANT|        SINGLE|          7| 46086|      27201|            9|  1,682,942|      7|       29654|               5|                 8|      null|
# |  AGRICULTURE|    IB14615| 59|  MALE|             DENTIST|       MARRIED|          5| 81507|      25958|            3|    831,263|      1|       63833|               8|                 7|      null|
# |  AGRICULTURE|    IB14675| 56|  MALE|AGRICULTURAL ENGI...|       MARRIED|          4| 88768|      23866|            3|    560,187|      5|       31603|               1|                 9|      null|
# |  AGRICULTURE|    IB14771| 44|FEMALE|              POLICE|        SINGLE|          4| 80769|      41529|            3|  1,458,057|      3|       74975|               5|                 1|      null|
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# only showing top 5 rows
#
# Outer Join (SparkSQL)
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |Customer_ID|Age|Gender|          Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Category|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill|Risk Level|
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |    IB14589| 56|  MALE|              FARMER|        SINGLE|          3| 51162|      12591|            9|  AGRICULTURE|    104,758|      3|       75535|               2|                 1|      null|
# |    IB14604| 52|  MALE|          ACCOUNTANT|        SINGLE|          7| 46086|      27201|            9|  AGRICULTURE|  1,682,942|      7|       29654|               5|                 8|      null|
# |    IB14615| 59|  MALE|             DENTIST|       MARRIED|          5| 81507|      25958|            3|  AGRICULTURE|    831,263|      1|       63833|               8|                 7|      null|
# |    IB14675| 56|  MALE|AGRICULTURAL ENGI...|       MARRIED|          4| 88768|      23866|            3|  AGRICULTURE|    560,187|      5|       31603|               1|                 9|      null|
# |    IB14771| 44|FEMALE|              POLICE|        SINGLE|          4| 80769|      41529|            3|  AGRICULTURE|  1,458,057|      3|       74975|               5|                 1|      null|
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# only showing top 5 rows

# %%
print("Left Join (PySpark)")
loan.join(risk_df, on="Loan Category", how="left").show(5)

print("Left Join (SparkSQL)")
spark.sql("""
    SELECT l.*, r.`Risk Level`
    FROM loan l
    LEFT JOIN risk r
    ON l.`Loan Category` = r.`Loan Category`
""").show(5)
# Out:
# Left Join (PySpark)
# +-------------+-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# |Loan Category|Customer_ID|Age|Gender|  Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill| Risk Level|
# +-------------+-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# |      HOUSING|    IB14001| 30|  MALE|BANK MANAGER|        SINGLE|          4| 50000|      22199|            6| 10,00,000 |      5|      42,898|               6|                 9|  High Risk|
# |     SHOPPING|    IB14008| 44|  MALE|   PROFESSOR|       MARRIED|          6| 51000|      19999|            4|     50,000|      3|      33,999|               1|                 5|   Low Risk|
# |   TRAVELLING|    IB14012| 30|FEMALE|     DENTIST|        SINGLE|          3| 58450|      27675|            5|     75,000|      6|      20,876|               3|                 1|Medium Risk|
# |    GOLD LOAN|    IB14018| 29|  MALE|     TEACHER|       MARRIED|          5| 45767|      12787|            3|  6,00,000 |      7|      11,000|               0|                 4|Medium Risk|
# |   AUTOMOBILE|    IB14022| 34|  MALE|      POLICE|        SINGLE|          4| 43521|      11999|            3|  2,00,000 |      2|      43,898|               1|                 2|  High Risk|
# +-------------+-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# only showing top 5 rows
#
# Left Join (SparkSQL)
# +-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# |Customer_ID|Age|Gender|  Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Category|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill| Risk Level|
# +-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# |    IB14001| 30|  MALE|BANK MANAGER|        SINGLE|          4| 50000|      22199|            6|      HOUSING| 10,00,000 |      5|      42,898|               6|                 9|  High Risk|
# |    IB14008| 44|  MALE|   PROFESSOR|       MARRIED|          6| 51000|      19999|            4|     SHOPPING|     50,000|      3|      33,999|               1|                 5|   Low Risk|
# |    IB14012| 30|FEMALE|     DENTIST|        SINGLE|          3| 58450|      27675|            5|   TRAVELLING|     75,000|      6|      20,876|               3|                 1|Medium Risk|
# |    IB14018| 29|  MALE|     TEACHER|       MARRIED|          5| 45767|      12787|            3|    GOLD LOAN|  6,00,000 |      7|      11,000|               0|                 4|Medium Risk|
# |    IB14022| 34|  MALE|      POLICE|        SINGLE|          4| 43521|      11999|            3|   AUTOMOBILE|  2,00,000 |      2|      43,898|               1|                 2|  High Risk|
# +-----------+---+------+------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+-----------+
# only showing top 5 rows

# %%
print("Right Join (PySpark)")
loan.join(risk_df, on="Loan Category", how="right").show(5)

print("Right Join (SparkSQL)")
spark.sql("""
    SELECT l.*, r.`Risk Level`
    FROM loan l
    RIGHT JOIN risk r
    ON l.`Loan Category` = r.`Loan Category`
""").show(5)
# Out:
# Right Join (PySpark)
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |Loan Category|Customer_ID|Age|Gender|          Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill|Risk Level|
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |      HOUSING|    IB15107| 46|FEMALE| CHARTERED APPRAISER|       MARRIED|          2| 85088|      44256|            5|    347,254|      9|       37966|               1|                 5| High Risk|
# |      HOUSING|    IB15095| 53|FEMALE|   SOFTWARE ENGINEER|        SINGLE|          4| 75210|      26027|            7|    740,375|      7|       35419|               2|                 4| High Risk|
# |      HOUSING|    IB15091| 42|  MALE|AGRICULTURAL ENGI...|       MARRIED|          2| 66610|      35744|            4|    582,943|      8|       28192|               0|                 8| High Risk|
# |      HOUSING|    IB15084| 36|FEMALE|               CLERK|       MARRIED|          4| 38000|      19000|            3|  3,00,000 |      2|       5,600|               4|                 8| High Risk|
# |      HOUSING|    IB15024| 26|  MALE|           DIETICIAN|        SINGLE|          3| 95425|      53086|            2|    488,076|      4|       61227|               5|                 2| High Risk|
# +-------------+-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-----------+-------+------------+----------------+------------------+----------+
# only showing top 5 rows
#
# Right Join (SparkSQL)
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |Customer_ID|Age|Gender|          Occupation|Marital Status|Family Size|Income|Expenditure|Use Frequency|Loan Category|Loan Amount|Overdue| Debt Record| Returned Cheque| Dishonour of Bill|Risk Level|
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# |    IB15107| 46|FEMALE| CHARTERED APPRAISER|       MARRIED|          2| 85088|      44256|            5|      HOUSING|    347,254|      9|       37966|               1|                 5| High Risk|
# |    IB15095| 53|FEMALE|   SOFTWARE ENGINEER|        SINGLE|          4| 75210|      26027|            7|      HOUSING|    740,375|      7|       35419|               2|                 4| High Risk|
# |    IB15091| 42|  MALE|AGRICULTURAL ENGI...|       MARRIED|          2| 66610|      35744|            4|      HOUSING|    582,943|      8|       28192|               0|                 8| High Risk|
# |    IB15084| 36|FEMALE|               CLERK|       MARRIED|          4| 38000|      19000|            3|      HOUSING|  3,00,000 |      2|       5,600|               4|                 8| High Risk|
# |    IB15024| 26|  MALE|           DIETICIAN|        SINGLE|          3| 95425|      53086|            2|      HOUSING|    488,076|      4|       61227|               5|                 2| High Risk|
# +-----------+---+------+--------------------+--------------+-----------+------+-----------+-------------+-------------+-----------+-------+------------+----------------+------------------+----------+
# only showing top 5 rows
